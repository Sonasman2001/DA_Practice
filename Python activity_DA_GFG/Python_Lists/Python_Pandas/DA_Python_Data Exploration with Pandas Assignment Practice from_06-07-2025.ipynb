# %%
import pandas as pd

# %%
# !git clone https://github.com/AshishJangra27/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 332, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 332 (delta 20), reused 54 (delta 9), pack-reused 235 (from 1)
# Receiving objects: 100% (332/332), 278.70 MiB | 16.93 MiB/s, done.
# Resolving deltas: 100% (146/146), done.
# Updating files: 100% (226/226), done.

# %%
df = pd.read_csv('/content/datasets/Gaana/songs.csv')

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df = pd.read_csv('/content/datasets/Gaana/songs.csv')

df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df.tail()
# Out:
#                                                     name  \
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 41350                   Kishore Kumar
# 41351                    Feroza Begum
# 41352  Sandhya Mukherjee|Hemant Kumar
# 41353                Ajoy Chakrabarty
# 41354                     Asha Bhosle
#
#                                                singer_id duration  \
# 41350                              /artist/kishore-kumar    03:23
# 41351                               /artist/feroza-begum    03:56
# 41352  /artist/sandhya-mukherjee|/artist/hemanta-mukh...    07:36
# 41353                           /artist/ajoy-chakrabarty    04:29
# ...

# %%
df['name']
# Out:
# 0                                    Dil - E - Nadan Tujhe
# 1                        Agar Hum Kahen Aur Woh Muskara De
# 2                                            Unke Dekhe Se
# 3                  Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                  Hazaron Khwahishen Aisi
#                                ...
# 41350    Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                  Ei Ki Go Shesh Daan
# 41352                                         Ei Je Bangla
# 41353                                 Jatone Hridaye Rekho
# 41354                              Tomar Je Oi Haater Mala
# Name: name, Length: 41355, dtype: object

# %%
df['duration']
# Out:
# 0        05:00
# 1        06:26
# 2        03:41
# 3        04:26
# 4        05:39
#          ...
# 41350    03:23
# 41351    03:56
# 41352    07:36
# 41353    04:29
# 41354    03:22
# Name: duration, Length: 41355, dtype: object

# %%
df.describe()
# Out:
#                        name           singer                singer_id  \
# count                 41355            41355                    41355
# unique                31534             6196                     6580
# top     O Mere Dil Ke Chain  Lata Mangeshkar  /artist/lata-mangeshkar
# freq                     26             1410                     1410
#
#        duration                       link language
# count     41355                      41355    41355
# unique     1309                      36361       16
# top       03:02  /ek-baar-zara-phir-keh-do   Telugu
# freq        447                          2     4996

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41355 entries, 0 to 41354
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       41355 non-null  object
#  1   singer     41355 non-null  object
#  2   singer_id  41355 non-null  object
#  3   duration   41355 non-null  object
#  4   link       41355 non-null  object
#  5   language   41355 non-null  object
# dtypes: object(6)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %%
df['link'].nunique()
# Out:
# 36361

# %%
df['singer_id'].nunique()
# Out:
# 6580

# %%
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
unique_languages = df['language'].unique()
print(unique_languages)
# Out:
# ['Urdu' 'Gujarati' 'Tamil' 'Kannada' 'Rajasthani' 'Haryanvi' 'Punjabi'
#  'Hindi' 'Old' 'Malayalam' 'Marathi' 'Telugu' 'Odia' 'Bhojpuri' 'Assamese'
#  'Bengali']

# %%
for language in df['language'].unique():
  print(language, len(df[df['language'] == language]))
# Out:
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4996
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %%
df['name'].value_counts().sort_values(ascending=False).head(20).plot(kind = 'barh')
# Out:
# <Axes: ylabel='name'>

# %%
df['language'].value_counts().sort_values(ascending=True).plot(kind = 'bar')
# Out:
# <Axes: xlabel='language'>

# %%
df['singer_id'].str.split('|').explode().nunique()
# Out:
# 4528

# %%
lst = []

for i in df['singer_id']:
  lst += (i.split('|'))

# %%
len(set(lst))
# Out:
# 4528

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df['singer_id'].value_counts().head(10)
# Out:
# singer_id
# /artist/lata-mangeshkar                              1410
# /artist/asha-bhosle-1                                1274
# /artist/kishore-kumar                                1213
# /artist/mohammad-rafi                                1201
# /artist/s-p-balasubrahamanyam                        1168
# /artist/p-suseela-2                                  1019
# /artist/s-janaki                                      730
# /artist/s-p-balasubrahamanyam|/artist/p-suseela-2     682
# /artist/noor-jehan                                    490
# /artist/s-p-balasubrahamanyam|/artist/s-janaki        455
# Name: count, dtype: int64

# %%
df['singer_id'].str.split('|').explode().value_counts().head(10).plot(kind = 'barh')
# Out:
# <Axes: ylabel='singer_id'>

# %%
df['singer'].str.split('|').explode().value_counts().sort_values(ascending = False).head().plot(kind = 'barh')
# Out:
# <Axes: ylabel='singer'>

# %%
df['singer'].str.split('|').explode().value_counts()
# Out:
# singer
# S. P. Balasubrahmanyam    3659
# P. Susheela               3212
# Lata Mangeshkar           3056
# Asha Bhosle               2715
# Kishore Kumar             2401
#                           ...
# Sanat Singha                 1
# Anusuya Ghosh                1
# Arghya Sen                   1
# Sailen Mukherjee             1
# Ayesha Sarkar                1
# Name: count, Length: 3940, dtype: int64

# %%
df[df['duration'] == '06:52:00']
# Out:
#                  name          singer               singer_id  duration  \
# 15000  Bum Bum Lahiri  Dilshad Akhtar  /artist/dilshad-akhtar  06:52:00
# 16352  Bum Bum Lahiri  Dilshad Akhtar  /artist/dilshad-akhtar  06:52:00
#
#                     link language
# 15000  /bum-bum-lahiri-1  Punjabi
# 16352    /bum-bum-lahiri  Punjabi

# %%
for i in df['duration'].unique():
  if len(i.split(':')) != 2:
    print(i)
# Out:
# 01:00:21
# 01:00:09
# 01:00:08
# 01:09:52
# 01:15:45
# 01:05:53
# 01:08:04
# 01:00:39
# 05:43:00
# 06:03:00
# 01:00:45
# 05:48:00
# 05:17:00
# 04:20:00
# 06:52:00
# 06:04:00
# 05:25:00
# 05:05:00
# 06:02:00
# 01:16:00
# 05:16:00
# 05:33:00
# 05:00:00
# 01:23:22
# 07:08:00
# 01:02:27
# 01:01:08
# 01:04:36
# 01:00:05
# 01:07:13
# 02:01:49
# 02:04:37
# 02:22:18
# 01:09:22
# 01:06:19
# 02:17:29
# 02:26:54
# 01:04:35
# 01:49:40
# 02:37:42
# 02:05:46
# 02:13:06
# 02:20:03
# 01:07:12
# 01:54:41
# 02:27:29
# 02:04:16
# 02:20:24
# 01:02:51
# 02:53:29
# 01:52:12
# 01:07:38
# 01:05:27
# 01:10:41
# 01:01:05
# 02:25:50
# 01:01:00

# %%
df[(df['language'] == 'Hindi') | (df['language'] == 'Old')]['link'].value_counts()
# Out:
# link
# /diwana-leke-aaya-hai-7           2
# /hum-to-hai-chui-mui-2            2
# /teri-meri-dosti-ho-gai           2
# /jeevan-se-bhari-teri-ankhen-9    2
# /gawah-hai-chand-tare             2
#                                  ..
# /kora-kagaz-tha-yeh-man-mera-1    2
# /tere-bina-zindagi-se-1           2
# /hamen-tumse-pyar-kitna-2         2
# /tum-aa-gaye-ho-noor-aa-gaya      2
# /aap-ki-ankhon-mein-kuchh         2
# Name: count, Length: 4993, dtype: int64

# %%
len(df[df['language'] == 'Old'])
# Out:
# 4993

# %%
len(df[df['language'] == 'Hindi'])
# Out:
# 4993

# %%
df['name'] + ' by ' + df['singer'].str.replace('|',',')
# Out:
# 0        Dil - E - Nadan Tujhe by Chitra Singh,Jagjit S...
# 1        Agar Hum Kahen Aur Woh Muskara De by Chitra Si...
# 2                            Unke Dekhe Se by Jagjit Singh
# 3        Yeh Na Thi Hamari Qismat - Chitra Singh by Chi...
# 4                  Hazaron Khwahishen Aisi by Jagjit Singh
#                                ...
# 41350    Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                  Ei Ki Go Shesh Daan by Feroza Begum
# 41352       Ei Je Bangla by Sandhya Mukherjee,Hemant Kumar
# 41353             Jatone Hridaye Rekho by Ajoy Chakrabarty
# 41354               Tomar Je Oi Haater Mala by Asha Bhosle
# Length: 41355, dtype: object
